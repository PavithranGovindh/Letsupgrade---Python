# %% [markdown]
# # Assignment 1

# %%
! pip install pylint
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting pylint
#   Downloading pylint-2.6.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 3.2 MB/s eta 0:00:01
# Collecting isort<6,>=4.2.5
#   Downloading isort-5.5.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 5.0 MB/s  eta 0:00:01
# Collecting mccabe<0.7,>=0.6
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting toml>=0.7.1
#   Downloading toml-0.10.1-py2.py3-none-any.whl (19 kB)
# Collecting astroid<=2.5,>=2.4.0
#   Downloading astroid-2.4.2-py3-none-any.whl (213 kB)
#      |████████████████████████████████| 213 kB 18.4 MB/s eta 0:00:01
# Collecting lazy-object-proxy==1.4.*
#   Downloading lazy_object_proxy-1.4.3-cp37-cp37m-manylinux1_x86_64.whl (56 kB)
#      |████████████████████████████████| 56 kB 5.2 MB/s  eta 0:00:01
# Collecting wrapt~=1.11
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8"
#   Downloading typed_ast-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (737 kB)
#      |████████████████████████████████| 737 kB 19.5 MB/s eta 0:00:01
# Requirement already satisfied: six~=1.12 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from astroid<=2.5,>=2.4.0->pylint) (1.14.0)
# Building wheels for collected packages: wrapt
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=70951 sha256=f9641ae45562c9e8a86ab910768a7518730380298d9ee2c851bcb1493cfda920
#   Stored in directory: /home/jovyan/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# Installing collected packages: isort, mccabe, toml, lazy-object-proxy, wrapt, typed-ast, astroid, pylint
# Successfully installed astroid-2.4.2 isort-5.5.2 lazy-object-proxy-1.4.3 mccabe-0.6.1 pylint-2.6.0 toml-0.10.1 typed-ast-1.4.1 wrapt-1.12.1

# %%
# %%writefile primeNumber.py
'''declaring primenumber function'''

def prime_number(num):
    '''to check the given number is prime or not'''
    for i in range(2,num):
        if num%i==0:
            break
    else:
        return num
# Out:
# Overwriting primeNumber.py

# %%
# !pylint prime_number.py
# Out:
# ************* Module prime_number
# prime_number.py:11:0: C0304: Final newline missing (missing-final-newline)
#
# ------------------------------------------------------------------
# Your code has been rated at 8.33/10 (previous run: 8.33/10, +0.00)

# %%
import primeNumber

primeNumber.prime_number(17)
# Out:
# 17

# %%
# %%writefile testPrimeNumber.py

import unittest
import primeNumber

class testPrime(unittest.TestCase):
    def testOne(self):
        temp = 17
        result = primeNumber.prime_number(temp)
        self.assertEquals(result, 17)
    def testTwo(self):
        temp = 21
        result = primeNumber.prime_number(temp)
        self.assertEquals(result, 21)

if __name__ == "__main__":
    unittest.main()
# Out:
# Overwriting testPrimeNumber.py

# %%
# !python testPrimeNumber.py
# Out:
# testPrimeNumber.py:9: DeprecationWarning: Please use assertEqual instead.
#   self.assertEquals(result, 17)
# .F
# ======================================================================
# FAIL: testTwo (__main__.testPrime)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "testPrimeNumber.py", line 13, in testTwo
#     self.assertEquals(result, 21)
# AssertionError: None != 21
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.001s
#
# FAILED (failures=1)

# %% [markdown]
# # Assignment 2

# %%
#generator function
def armStrongGen(lst):
    for item in lst:
        sum=0
        temp=item
        while temp > 0:
            sum = sum + ((temp%10)**3)
            temp//=10
        
        if sum == item:
            yield item

            
# main

lst=list(range(1,1000))
print(list(armStrongGen(lst)))
# Out:
# [1, 153, 370, 371, 407]
